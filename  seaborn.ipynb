# %%
import pandas as pd 
import seaborn as sns

# %%
data={
'car':['BMW','BENZ','INNOVA','Swift', 'Baleno', 'Brezza', 'Dzire'],
#year=[2020,2021,2022,2023,2024,2025,2026]
'sales_2023':[900,100,400,600,100,500,300],
'sales_2024':[90,120,410,604,10,507,30],
'sales_2025':[50,190,44,309,103,50,90],
'sales_2026':[990,10,120,400,800,900,30]
}
data
# Out:
# {'car': ['BMW', 'BENZ', 'INNOVA', 'Swift', 'Baleno', 'Brezza', 'Dzire'],
#  'sales_2023': [900, 100, 400, 600, 100, 500, 300],
#  'sales_2024': [90, 120, 410, 604, 10, 507, 30],
#  'sales_2025': [50, 190, 44, 309, 103, 50, 90],
#  'sales_2026': [990, 10, 120, 400, 800, 900, 30]}

# %%
df=pd.DataFrame(data)
df
# Out:
#       car  sales_2023  sales_2024  sales_2025  sales_2026
# 0     BMW         900          90          50         990
# 1    BENZ         100         120         190          10
# 2  INNOVA         400         410          44         120
# 3   Swift         600         604         309         400
# 4  Baleno         100          10         103         800
# 5  Brezza         500         507          50         900
# 6   Dzire         300          30          90          30

# %%
sns.lineplot(x='car',y='sales_2023',data=df,color='red',marker='o')
# Out:
# <Axes: xlabel='car', ylabel='sales_2023'>

# %%
sns.barplot(x='car',y='sales_2023',data=df,color='red')
# Out:
# <Axes: xlabel='car', ylabel='sales_2023'>
